# %% [markdown]
# <a href="https://colab.research.google.com/github/irealand-fearP/AIFFEL_quest_eng/blob/main/Python/Py05/Quest05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random        #계좌번호 랜덤생성위해 호출

class Account:
  account = 0


  def __init__(self, name, balance):
    self.bank="SC은행"
    self.name= name
    self.balance=balance
    self.deposit_count=0

    num1=random.randint(0, 999)
    num2=random.randint(0, 99)
    num3=random.randint(0, 999999)

    self.account_number=f"{num1}-{num2}-{num3}"
    Account.account += 1 #Q3

  def deposit(self, amount):  #Q4
    if amount >=1:
      self.balance += amount
      self.deposit_count += 1

    if self.deposit_count % 5 == 0:
       self.balance += (self.balance * 0.01)



  def withdraw(self, amount):
    if self.balance >= amount:
       self.balance -= amount
       print(f"{amount}원 출금되었습니다. (잔액: {self.balance}원)")
    else:
       print("잔액이 부족합니다.")

  def dissplay_info(self):
    print(f"은행이름: {self.bank}")
    print(f"예금주: {self.name}")
    print(f"계좌번호: {self.account_number}")
    print(f"잔액: {self.balance}원")

# %%
kim = Account("김동건", 10000000)
lee = Account("이동건", 50000000)
jang = Account("장동건", 9999999)

account_list = [kim, lee, jang]

# %%
print("-" * 25)
print("잔고 100만원이상 명단" )
print("-" * 25)
for acc in account_list:
  if acc.balance >= 1000000:
    acc.dissplay_info()
    print("-"*25)
# Out:
# -------------------------
# 잔고 100만원이상 명단
# -------------------------
# 은행이름: SC은행
# 예금주: 김동건
# 계좌번호: 738-26-109179
# 잔액: 10000000원
# -------------------------
# 은행이름: SC은행
# 예금주: 이동건
# 계좌번호: 725-3-16200
# 잔액: 50000000원
# -------------------------
# 은행이름: SC은행
# 예금주: 장동건
# 계좌번호: 735-65-604534
# 잔액: 9999999원
# -------------------------

# %%
import random        #계좌번호 랜덤생성위해 호출

class Account:
  account = 0  #Q2


  def __init__(self, name, balance):  #Q1 기본정보 세팅
    self.bank="SC은행"
    self.name= name
    self.balance=balance
    self.deposit_count=0

    num1=random.randint(0, 999)  #Q1 계좌번호 3자리 2자리 6자리 생성
    num2=random.randint(0, 99)
    num3=random.randint(0, 999999)

    self.deposit_history_log =[]  #Q 10 입금내역 저장할 리스트 생성
    self.withdraw_history_log = []

    self.account_number=f"{num1}-{num2}-{num3}"
    Account.account += 1
    #Q3
  def get_account_num(self):
    print(cls.account)

  def deposit(self, amount):  #Q4 입금 메서드
    if amount >=1:
      self.balance += amount
      self.deposit_count += 1

      self.deposit_history_log.append(amount)

    if self.deposit_count % 5 == 0:
       self.balance += (self.balance * 0.01)

       self.balance += "interest" # = 이자
       self.deposit_history_log.append({interest})

    else:
      print("입금은 1원 이상만 가능합니다.")



  def withdraw(self, amount):
    if self.balance >= amount:
       self.balance -= amount
       print(f"{amount}원 출금되었습니다. (잔액: {self.balance}원)")
    else:
       print("잔액이 부족합니다.")

  def dissplay_info(self):
    print(f"은행이름: {self.bank}")
    print(f"예금주: {self.name}")
    print(f"계좌번호: {self.account_number}")
    print(f"잔액: {self.balance}원")


  def deposit_history_log(self):
    print(f"입금내역 : {self.name}")
    for i in self.deposit_history_log:
      print(f"입금액 : {i}원")

  def withdraw_history_log(self):
    print(f"출금내역 : {self.name}")
    for i in(self.withdraw_history_log):
      print(f"출금액 : {i}원")

# %%
kim = Account("김동건", 10000000)
lee = Account("이동건", 50000000)
jang = Account("장동건", 9999999)

account_list = [kim, lee, jang]

# %%
import random        #계좌번호 랜덤생성위해 호출

class Account:
  account = 0  #Q2


  def __init__(self, name, balance):  #Q1 기본정보 세팅
    self.bank="SC은행"
    self.name= name
    self.balance=balance
    self.deposit_count=0

    num1=random.randint(0, 999)  #Q1 계좌번호 3자리 2자리 6자리 생성
    num2=random.randint(0, 99)
    num3=random.randint(0, 999999)

    self.deposit_history_log =[]  #Q 10 입금내역 저장할 리스트 생성
    self.withdraw_history_log = []

    self.account_number=f"{num1}-{num2}-{num3}"
    Account.account += 1
    #Q3
  def get_account_num(self):
    print(countls.acc)

  def deposit(self, amount):  #Q4 입금 메서드
    if amount >=1:
      self.balance += amount
      self.deposit_count += 1

      self.deposit_history_log.append(amount)

      if self.deposit_count % 5 == 0:
          interest = self.balance * 0.01
          self.balance += interest # = 이자
          self.deposit_history_log.append({interest})

    else:
      print("입금은 1원 이상만 가능합니다.")



  def withdraw(self, amount):
    if self.balance >= amount:
       self.balance -= amount
       print(f"{amount}원 출금되었습니다. (잔액: {self.balance}원)")
    else:
       print("잔액이 부족합니다.")

  def dissplay_info(self):
    print(f"은행이름: {self.bank}")
    print(f"예금주: {self.name}")
    print(f"계좌번호: {self.account_number}")
    print(f"잔액: {self.balance:,}원")


  def display_deposit_history(self):
    print(f"입금내역 : {self.name}")
    for i in self.display_deposit_history:
      print(f"입금액 : {i:,}원")

  def display_withdraw_history(self):
    print(f"출금내역 : {self.name}")
    for i in self.display_deposit_history:
      print(f"출금액 : {i:,}원")

# %%
kim = Account("김동건", 10000000)
lee = Account("이동건", 50000000)
jang = Account("장동건", 9999999)

account_list = [kim, lee, jang]

# %%
print("-" * 25)
print("잔고 100만원이상 명단" )
print("-" * 25)
for acc in account_list:
  if acc.balance >= 1000000:
    acc.display_info()
    print("-"*25)
# Out:
# -------------------------
# 잔고 100만원이상 명단
# -------------------------
# 은행이름: SC은행
# 예금주: 김동건
# 계좌번호: 485-93-494641
# 잔액: 10,104,050.0원
# -------------------------
# 은행이름: SC은행
# 예금주: 이동건
# 계좌번호: 757-99-135931
# 잔액: 50,000,000원
# -------------------------
# 은행이름: SC은행
# 예금주: 장동건
# 계좌번호: 338-12-366479
# 잔액: 9,999,999원
# -------------------------

# %%
kim.deposit(1000)
kim.deposit(1000)
kim.deposit(1000)
kim.deposit(1000)
kim.deposit(1000)
kim.withdraw(1000)
# Out:
# 1000원 출금되었습니다. (잔액: 10104050.0원)

# %%
kim.deposit_history_log()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6858/804954477.py in <cell line: 0>()
# ----> 1 kim.deposit_history_log()
#
# TypeError: 'list' object is not callable

# %%
import random        #계좌번호 랜덤생성위해 호출

class Account:
  account = 0  #Q2


  def __init__(self, name, balance):  #Q1 기본정보 세팅
    self.bank="SC은행"
    self.name= name
    self.balance=balance
    self.deposit_count=0

    num1=random.randint(0, 999)  #Q1 계좌번호 3자리 2자리 6자리 생성
    num2=random.randint(0, 99)
    num3=random.randint(0, 999999)

    self.deposit_history_log =[]  #Q 10 입금내역 저장할 리스트 생성
    self.withdraw_history_log = []

    self.account_number=f"{num1}-{num2}-{num3}"
    Account.account += 1
    #Q3
  def get_account_num(self):
    print(f"생성된 계좌수 : {Account.account}")

  def deposit(self, amount):  #Q4 입금 메서드
    if amount >=1:
      self.balance += amount
      self.deposit_count += 1

      self.deposit_history_log.append(amount)

      if self.deposit_count % 5 == 0:
          interest = self.balance * 0.01
          self.balance += interest # = 이자
          self.deposit_history_log.append({interest})

    else:
      print("입금은 1원 이상만 가능합니다.")



  def withdraw(self, amount):
    if self.balance >= amount:
       self.balance -= amount
       print(f"{amount}원 출금되었습니다. (잔액: {self.balance}원)")
    else:
       print("잔액이 부족합니다.")

  def display_info(self):
    print(f"은행이름: {self.bank}")
    print(f"예금주: {self.name}")
    print(f"계좌번호: {self.account_number}")
    print(f"잔액: {self.balance:,}원")


  def display_deposit_history(self):
    print(f"입금내역 : {self.name}")
    print(f"입금액 : {self.deposit_history_log}원")

  def display_withdraw_history(self):
    print(f"출금내역 : {self.name}")
    print(f"출금액 : {self.withdraw_history_log:,}원")

# %%
kim = Account("김동건", 10000000)
lee = Account("이동건", 50000000)
jang = Account("장동건", 9999999)

account_list = [kim, lee, jang]

# %%
kim.display_info()
# Out:
# 은행이름: SC은행
# 예금주: 김동건
# 계좌번호: 485-93-494641
# 잔액: 10,000,000원

# %%
kim.deposit(1000)
kim.deposit(1000)
kim.deposit(1000)
kim.deposit(1000)
kim.deposit(1000)
kim.withdraw(1000)
# Out:
# 1000원 출금되었습니다. (잔액: 10104050.0원)

# %%
kim.display_deposit_history()
# Out:
# 입금내역 : 김동건
# 입금액 : [1000, 1000, 1000, 1000, 1000, {100050.0}]원

# %%
print("-" * 25)
print("잔고 100만원이상 명단" )
print("-" * 25)
for acc in account_list:
  if acc.balance >= 1000000:
    acc.display_info()
    print("-"*25)
# Out:
# -------------------------
# 잔고 100만원이상 명단
# -------------------------
# 은행이름: SC은행
# 예금주: 김동건
# 계좌번호: 485-93-494641
# 잔액: 10,104,050.0원
# -------------------------
# 은행이름: SC은행
# 예금주: 이동건
# 계좌번호: 757-99-135931
# 잔액: 50,000,000원
# -------------------------
# 은행이름: SC은행
# 예금주: 장동건
# 계좌번호: 338-12-366479
# 잔액: 9,999,999원
# -------------------------

# %%
print(kim.get_account_num())
# Out:
# 생성된 계좌수 : 3
# None
